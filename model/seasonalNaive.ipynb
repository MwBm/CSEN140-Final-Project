# %% [markdown]
# # SeasonalNaive model based on last weeks wait times

# %%
# Load in data
import pandas as pd
final_merged_df = pd.read_csv('../data/final_merged_data.csv', parse_dates=['Local Time'])

# Print preliminary data
print(f"Loaded {len(final_merged_df):,} records")
print(f"Number of unique rides: {final_merged_df['Ride'].nunique()}")

# Print a list of all unique ride names along with the number of records for each ride.
# This provides an overview of data distribution across rides.
print(f"\nUnique rides:")
for ride in sorted(final_merged_df['Ride'].unique()):
    count = len(final_merged_df[final_merged_df['Ride'] == ride])
    print(f"  {ride}: {count:,} records")
# Out:
# /var/folders/pp/vwp6cpmd6xd962fpyb8gjv5w0000gn/T/ipykernel_22932/1897747226.py:3: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   final_merged_df = pd.read_csv('../data/final_merged_data.csv', parse_dates=['Local Time'])
# Loaded 589,985 records
# Number of unique rides: 42
#
# Unique rides:
#   Animation Academy: 18,021 records
#   Games of Pixar Pier: 16,166 records
#   Golden Zephyr: 18,021 records
#   Goofy's Sky School: 18,021 records
#   Grizzly River Run: 18,021 records
#   Guardians of the Galaxy - Mission: BREAKOUT!: 18,021 records
#   Guardians of the Galaxy - Monsters After Dark: 9,754 records
#   Incredicoaster: 18,021 records
#   Incredicoaster Single Rider: 18,021 records
#   Inside Out Emotional Whirlwind: 18,021 records
#   Jessie's Critter Carousel: 18,021 records
#   Jumpin' Jellyfish: 18,021 records
#   Luigi's Honkin' Haul-O-Ween: 1,516 records
#   Luigi's Joy to the Whirl: 3,087 records
#   Luigi's Rollickin' Roadsters: 11,564 records
#   Mater's Graveyard JamBOOree: 3,344 records
#   Mater's Jingle Jamboree: 3,087 records
#   Mater's Junkyard Jamboree: 11,590 records
#   Incredicoaster: 18,021 records
#   Incredicoaster Single Rider: 18,021 records
#   Inside Out Emotional Whirlwind: 18,021 records
#   Jessie's Critter Carousel: 18,021 records
#   Jumpin' Jellyfish: 18,021 records
#   Luigi's Honkin' Haul-O-Ween: 1,516 records
#   Luigi's Joy to the Whirl: 3,087 records
#   Luigi's Rollickin' Roadsters: 11,564 records
#   Mater's Graveyard JamBOOree: 3,344 records
#   Mater's Jingle Jamboree: 3,087 records
#   Mater's Junkyard Jamboree: 11,590 records
#   Mickey's PhilharMagic: 18,021 records
#   Monsters, Inc. Mike & Sulley to the Rescue!: 18,021 records
#   Pixar Pal-A-Round - Swinging: 18,021 records
#   Pixar Pal-A-Round – Non-Swinging: 18,021 records
#   Radiator Springs Racers: 18,021 records
#   Radiator Springs Racers Single Rider: 18,021 records
#   Red Car Trolley: 16,847 records
#   Redwood Creek Challenge Trail: 18,021 records
#   Rogers: The Musical: 1,378 records
#   Silly Symphony Swings: 18,021 records
#   Mickey's PhilharMagic: 18,021 records
#   Monsters, Inc. Mike & Sulley to the Rescue!: 18,021 records
#   Pixar Pal-A-Round - Swinging: 18,021 records
#   Pixar Pal-A-Round – Non-Swinging: 18,021 records
#   Radiator Springs Racers: 18,021 records
#   Radiator Springs Racers Single Rider: 18,021 records
#   Red Car Trolley: 16,847 records
#   Redwood Creek Challenge Trail: 18,021 records
#   Rogers: The Musical: 1,378 records
#   Silly Symphony Swings: 18,021 records
#   Silly Symphony Swings Single Rider: 18,021 records
#   Soarin' Around the World: 15,120 records
#   Soarin' Over California: 2,901 records
#   Sorcerer's Workshop: 18,021 records
#   The Bakery Tour: 16,166 records
#   The Little Mermaid - Ariel's Undersea Adventure: 18,021 records
#   Toy Story Midway Mania!: 18,021 records
#   Turtle Talk with Crush: 18,021 records
#   Villains Grove at Oogie Boogie Bash: 3,259 records
#   WEB SLINGERS: A Spider-Man Adventure: 18,021 records
#   WEB SLINGERS: A Spider-Man Adventure Single Rider: 18,021 records
#   Silly Symphony Swings Single Rider: 18,021 records
#   Soarin' Around the World: 15,120 records
#   Soarin' Over California: 2,901 records
#   Sorcerer's Workshop: 18,021 records
#   The Bakery Tour: 16,166 records
#   The Little Mermaid - Ariel's Undersea Adventure: 18,021 records
#   Toy Story Midway Mania!: 18,021 records
#   Turtle Talk with Crush: 18,021 records
#   Villains Grove at Oogie Boogie Bash: 3,259 records
#   WEB SLINGERS: A Spider-Man Adventure: 18,021 records
#   WEB SLINGERS: A Spider-Man Adventure Single Rider: 18,021 records
#   Walt Disney Imagineering Blue Sky Cellar: 1,378 records
#   World of Color - Season of Light: 4,282 records
#   World of Color – ONE: 18,021 records
#   Walt Disney Imagineering Blue Sky Cellar: 1,378 records
#   World of Color - Season of Light: 4,282 records
#   World of Color – ONE: 18,021 records

# %%
# Split the main dataset into separate, time-sorted DataFrames for each
# ride and store them in a dictionary for easy per-ride analysis.
ride_dataframes = {}

for ride in final_merged_df['Ride'].unique():
    ride_df = final_merged_df[final_merged_df['Ride'] == ride].copy()
    ride_df = ride_df.sort_values('Local Time').reset_index(drop=True)
    ride_dataframes[ride] = ride_df

# %%
# Feature Engineering and Seasonal Naive Baseline
from sklearn.metrics import mean_absolute_error

# We'll store baseline MAE results for each ride
baseline_results = {}

# Loop over each ride's data
for ride, df in ride_dataframes.items():
    
    # Feature Engineering (make raw data easier to use)
    df['hour'] = df['Local Time'].dt.hour
    df['day_of_week'] = df['Local Time'].dt.dayofweek
    df['month'] = df['Local Time'].dt.month
    df['is_weekend'] = df['day_of_week'].isin([5,6]).astype(int)
    
    # Create a Seasonal Naive feature
    # Prediction = wait time at same time last week
    lag = 7*24*4                                                # Data is at 15-minute intervals, so lag = 7 days * 24 hours * 4 intervals/hour = 672
    df['Predicted Wait Time'] = df['Wait Time'].shift(lag)
    df.dropna(subset=['Predicted Wait Time'], inplace=True)     # Drop first week of rows that have no "previous week" value
    
    # Calculate baseline error (average absolute difference between predicted and actual wait times)
    mae = mean_absolute_error(df['Wait Time'], df['Predicted Wait Time'])
    baseline_results[ride] = mae
    
    # Save the updated DataFrame back to the dictionary
    ride_dataframes[ride] = df

# Display baseline MAE for each ride
for ride, mae in baseline_results.items():
    print(f"{ride}: Seasonal Naive MAE = {mae:.2f} minutes")
# Out:
# Guardians of the Galaxy - Mission: BREAKOUT!: Seasonal Naive MAE = 33.87 minutes
# Golden Zephyr: Seasonal Naive MAE = 6.26 minutes
# Goofy's Sky School: Seasonal Naive MAE = 23.17 minutes
# Silly Symphony Swings: Seasonal Naive MAE = 7.14 minutes
# Silly Symphony Swings Single Rider: Seasonal Naive MAE = 0.00 minutes
# The Little Mermaid - Ariel's Undersea Adventure: Seasonal Naive MAE = 14.35 minutes
# Games of Pixar Pier: Seasonal Naive MAE = 2.46 minutes
# Walt Disney Imagineering Blue Sky Cellar: Seasonal Naive MAE = 0.00 minutes
# Incredicoaster: Seasonal Naive MAE = 22.38 minutes
# Inside Out Emotional Whirlwind: Seasonal Naive MAE = 12.62 minutes
# Jessie's Critter Carousel: Seasonal Naive MAE = 2.30 minutes
# Jumpin' Jellyfish: Seasonal Naive MAE = 7.02 minutes
# Pixar Pal-A-Round - Swinging: Seasonal Naive MAE = 19.78 minutes
# Pixar Pal-A-Round – Non-Swinging: Seasonal Naive MAE = 18.51 minutes
# Toy Story Midway Mania!: Seasonal Naive MAE = 21.41 minutes
# Incredicoaster Single Rider: Seasonal Naive MAE = 0.00 minutes
# The Bakery Tour: Seasonal Naive MAE = 0.00 minutes
# World of Color – ONE: Seasonal Naive MAE = 0.00 minutes
# Sorcerer's Workshop: Seasonal Naive MAE = 0.00 minutes
# Turtle Talk with Crush: Seasonal Naive MAE = 0.00 minutes
# WEB SLINGERS: A Spider-Man Adventure: Seasonal Naive MAE = 21.94 minutes
# WEB SLINGERS: A Spider-Man Adventure Single Rider: Seasonal Naive MAE = 0.00 minutes
# Red Car Trolley: Seasonal Naive MAE = 0.00 minutes
# Luigi's Rollickin' Roadsters: Seasonal Naive MAE = 15.86 minutes
# Mater's Junkyard Jamboree: Seasonal Naive MAE = 12.25 minutes
# Radiator Springs Racers: Seasonal Naive MAE = 37.97 minutes
# Radiator Springs Racers Single Rider: Seasonal Naive MAE = 0.00 minutes
# Guardians of the Galaxy - Monsters After Dark: Seasonal Naive MAE = 14.03 minutes
# Redwood Creek Challenge Trail: Seasonal Naive MAE = 2.47 minutes
# Soarin' Around the World: Seasonal Naive MAE = 24.79 minutes
# Animation Academy: Seasonal Naive MAE = 0.00 minutes
# Mickey's PhilharMagic: Seasonal Naive MAE = 4.33 minutes
# Monsters, Inc. Mike & Sulley to the Rescue!: Seasonal Naive MAE = 21.84 minutes
# Rogers: The Musical: Seasonal Naive MAE = 0.00 minutes
# Grizzly River Run: Seasonal Naive MAE = 15.47 minutes
# Luigi's Honkin' Haul-O-Ween: Seasonal Naive MAE = 14.97 minutes
# Mater's Graveyard JamBOOree: Seasonal Naive MAE = 11.32 minutes
# Villains Grove at Oogie Boogie Bash: Seasonal Naive MAE = 0.00 minutes
# Luigi's Joy to the Whirl: Seasonal Naive MAE = 15.19 minutes
# Mater's Jingle Jamboree: Seasonal Naive MAE = 8.84 minutes
# World of Color - Season of Light: Seasonal Naive MAE = 0.00 minutes
# Soarin' Over California: Seasonal Naive MAE = 28.05 minutes

# %%
# Fraction of data to use for testing
test_fraction = 0.3

# Dictionary to store train/test sets per ride
ride_splits = {}

for ride, df in ride_dataframes.items():
    # Features we want to use for ML
    # Do one-hot encoding for columns where necessary
    feature_cols = [
        'hour', 'day_of_week', 'month', 'is_weekend',
        'temperature_2m (°F)', 'apparent_temperature (°F)', 'precipitation (mm)',
        'holiday_flag', 'tier', 'Land', 'holiday_name'
    ]
    target_col = 'Wait Time'    # Target variable
    
    # Determine index to split
    split_idx = int(len(df) * (1 - test_fraction))
    
    # Train/test split
    # We split the data chronologically (earlier rows for training, later rows for testing).
    # Randomly shuffling would let the model see the future, causing leakage. 
    # Chronological splitting ensures the model is trained on past data and evaluated on truly unseen future data.

    # I used .copy() for these, I'm not sure if that's necessary
    X_train = df[feature_cols].iloc[:split_idx].copy()
    X_test = df[feature_cols].iloc[split_idx:].copy()
    
    y_train = df[target_col].iloc[:split_idx].copy()
    y_test = df[target_col].iloc[split_idx:].copy()

    # One-hot encode categorical columns
    categorical_cols = ['tier', 'Land', 'holiday_name']
    X_train = pd.get_dummies(X_train, columns=categorical_cols, drop_first=False)
    X_test = pd.get_dummies(X_test, columns=categorical_cols, drop_first=False)
    
    # Align columns: ensure test set has same columns as train set
    X_test = X_test.reindex(columns=X_train.columns, fill_value=0)
    
    # Store in dictionary
    ride_splits[ride] = {
        'X_train': X_train,
        'y_train': y_train,
        'X_test': X_test,
        'y_test': y_test
    }
    
    print(f"{ride}: Train size = {len(X_train)}, Test size = {len(X_test)}")
# Out:
# Guardians of the Galaxy - Mission: BREAKOUT!: Train size = 12144, Test size = 5205
# Golden Zephyr: Train size = 12144, Test size = 5205
# Goofy's Sky School: Train size = 12144, Test size = 5205
# Silly Symphony Swings: Train size = 12144, Test size = 5205
# Silly Symphony Swings Single Rider: Train size = 12144, Test size = 5205
# The Little Mermaid - Ariel's Undersea Adventure: Train size = 12144, Test size = 5205
# Games of Pixar Pier: Train size = 10845, Test size = 4649
# Walt Disney Imagineering Blue Sky Cellar: Train size = 494, Test size = 212
# Incredicoaster: Train size = 12144, Test size = 5205
# Inside Out Emotional Whirlwind: Train size = 12144, Test size = 5205
# Jessie's Critter Carousel: Train size = 12144, Test size = 5205
# Jumpin' Jellyfish: Train size = 12144, Test size = 5205
# Pixar Pal-A-Round - Swinging: Train size = 12144, Test size = 5205
# Pixar Pal-A-Round – Non-Swinging: Train size = 12144, Test size = 5205
# Toy Story Midway Mania!: Train size = 12144, Test size = 5205
# Incredicoaster Single Rider: Train size = 12144, Test size = 5205
# The Bakery Tour: Train size = 10845, Test size = 4649
# World of Color – ONE: Train size = 12144, Test size = 5205
# Sorcerer's Workshop: Train size = 12144, Test size = 5205
# Turtle Talk with Crush: Train size = 12144, Test size = 5205
# WEB SLINGERS: A Spider-Man Adventure: Train size = 12144, Test size = 5205
# WEB SLINGERS: A Spider-Man Adventure Single Rider: Train size = 12144, Test size = 5205
# Red Car Trolley: Train size = 11322, Test size = 4853
# Luigi's Rollickin' Roadsters: Train size = 7624, Test size = 3268
# Mater's Junkyard Jamboree: Train size = 7642, Test size = 3276
# Radiator Springs Racers: Train size = 12144, Test size = 5205
# Radiator Springs Racers Single Rider: Train size = 12144, Test size = 5205
# Guardians of the Galaxy - Monsters After Dark: Train size = 6357, Test size = 2725
# Redwood Creek Challenge Trail: Train size = 12144, Test size = 5205
# Soarin' Around the World: Train size = 10113, Test size = 4335
# Animation Academy: Train size = 12144, Test size = 5205
# Mickey's PhilharMagic: Train size = 12144, Test size = 5205
# Monsters, Inc. Mike & Sulley to the Rescue!: Train size = 12144, Test size = 5205
# Rogers: The Musical: Train size = 494, Test size = 212
# Grizzly River Run: Train size = 12144, Test size = 5205
# Luigi's Honkin' Haul-O-Ween: Train size = 590, Test size = 254
# Mater's Graveyard JamBOOree: Train size = 1870, Test size = 802
# Villains Grove at Oogie Boogie Bash: Train size = 1810, Test size = 777
# Luigi's Joy to the Whirl: Train size = 1690, Test size = 725
# Mater's Jingle Jamboree: Train size = 1690, Test size = 725
# World of Color - Season of Light: Train size = 2527, Test size = 1083
# Soarin' Over California: Train size = 1560, Test size = 669

# %%
import xgboost as xgb
print(xgb.__version__)
# Out:
# 3.0.1

# %%
# Train XGBoost Models for Each Ride and Evaluate MAE

import xgboost as xgb
from sklearn.metrics import mean_absolute_error

# Dictionary to store trained models and MAE
ride_models = {}
ride_mae = {}

for ride, data in ride_splits.items():
    X_train = data['X_train']
    y_train = data['y_train']
    X_test = data['X_test']
    y_test = data['y_test']
    
    # Initialize XGBoost regressor
    xgb_model = xgb.XGBRegressor(
        n_estimators=100,
        max_depth=5,
        learning_rate=0.1,
        objective='reg:squarederror',
        random_state=42
    )
    
    # Train the model
    xgb_model.fit(X_train, y_train)
    
    # Make predictions
    y_pred = xgb_model.predict(X_test)
    
    # Evaluate MAE
    mae = mean_absolute_error(y_test, y_pred)
    
    # Save model and MAE
    ride_models[ride] = xgb_model
    ride_mae[ride] = mae
    
# Determine the maximum length of ride names for formatting
max_ride_length = max(len(ride) for ride in ride_splits.keys())

# Print header
header = f"{'Ride':<{max_ride_length}} | Seasonal Naive MAE | XGBoost MAE"
print(header)
print("-" * len(header))

# Print results
for ride in ride_splits.keys():
    naive_mae = baseline_results.get(ride, float('nan'))
    xgb_mae = ride_mae.get(ride, float('nan'))
    print(f"{ride:<{max_ride_length}} | {naive_mae:>17.2f} | {xgb_mae:>11.2f}")
# Out:
# Ride                                              | Seasonal Naive MAE | XGBoost MAE
# ------------------------------------------------------------------------------------
# Guardians of the Galaxy - Mission: BREAKOUT!      |             33.87 |       25.46
# Golden Zephyr                                     |              6.26 |        5.64
# Goofy's Sky School                                |             23.17 |       15.15
# Silly Symphony Swings                             |              7.14 |        5.82
# Silly Symphony Swings Single Rider                |              0.00 |        0.00
# The Little Mermaid - Ariel's Undersea Adventure   |             14.35 |       10.24
# Games of Pixar Pier                               |              2.46 |        2.38
# Walt Disney Imagineering Blue Sky Cellar          |              0.00 |        0.00
# Incredicoaster                                    |             22.38 |       15.55
# Inside Out Emotional Whirlwind                    |             12.62 |        8.20
# Jessie's Critter Carousel                         |              2.30 |        2.17
# Jumpin' Jellyfish                                 |              7.02 |        6.54
# Pixar Pal-A-Round - Swinging                      |             19.78 |       11.92
# Pixar Pal-A-Round – Non-Swinging                  |             18.51 |       11.07
# Toy Story Midway Mania!                           |             21.41 |       12.41
# Incredicoaster Single Rider                       |              0.00 |        0.00
# The Bakery Tour                                   |              0.00 |        0.00
# World of Color – ONE                              |              0.00 |        0.00
# Sorcerer's Workshop                               |              0.00 |        0.00
# Turtle Talk with Crush                            |              0.00 |        0.00
# WEB SLINGERS: A Spider-Man Adventure              |             21.94 |       14.93
# WEB SLINGERS: A Spider-Man Adventure Single Rider |              0.00 |        0.00
# Red Car Trolley                                   |              0.00 |        0.00
# Luigi's Rollickin' Roadsters                      |             15.86 |        9.45
# Mater's Junkyard Jamboree                         |             12.25 |        7.50
# Radiator Springs Racers                           |             37.97 |       29.09
# Radiator Springs Racers Single Rider              |              0.00 |        0.00
# Guardians of the Galaxy - Monsters After Dark     |             14.03 |        6.43
# Redwood Creek Challenge Trail                     |              2.47 |        1.76
# Soarin' Around the World                          |             24.79 |       22.13
# Animation Academy                                 |              0.00 |        0.00
# Mickey's PhilharMagic                             |              4.33 |        3.23
# Monsters, Inc. Mike & Sulley to the Rescue!       |             21.84 |       12.80
# Rogers: The Musical                               |              0.00 |        0.00
# Grizzly River Run                                 |             15.47 |       13.88
# Luigi's Honkin' Haul-O-Ween                       |             14.97 |       17.58
# Mater's Graveyard JamBOOree                       |             11.32 |        8.73
# Villains Grove at Oogie Boogie Bash               |              0.00 |        0.00
# Luigi's Joy to the Whirl                          |             15.19 |       12.83
# Mater's Jingle Jamboree                           |              8.84 |        6.58
# World of Color - Season of Light                  |              0.00 |        0.00
# Soarin' Over California                           |             28.05 |       15.33

# %%
# Cross-Validation and Hyperparameter Tuning for XGBoost Models

from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from sklearn.metrics import mean_absolute_error
import numpy as np

# Define hyperparameter grid for tuning
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.05, 0.1, 0.2],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0]
}

# Use TimeSeriesSplit for proper time series cross-validation
# This ensures we don't use future data to predict past data
tscv = TimeSeriesSplit(n_splits=5)

# Dictionaries to store the best models, parameters, and CV results
best_ride_models = {}
best_ride_params = {}
best_ride_mae_cv = {}

print("Starting cross-validation for each ride...")
print("This may take a few minutes...")
print()

for i, (ride, data) in enumerate(ride_splits.items()):
    print(f"Processing ride {i+1}/{len(ride_splits)}: {ride}")
    
    X_train = data['X_train']
    y_train = data['y_train']
    X_test = data['X_test']
    y_test = data['y_test']
    
    # Initialize base XGBoost model
    xgb_base = xgb.XGBRegressor(
        objective='reg:squarederror',
        random_state=42,
        n_jobs=-1  # Use all available cores
    )
    
    # Perform grid search with time series cross-validation
    grid_search = GridSearchCV(
        estimator=xgb_base,
        param_grid=param_grid,
        cv=tscv,
        scoring='neg_mean_absolute_error',
        n_jobs=-1,
        verbose=0
    )
    
    # Fit the grid search
    grid_search.fit(X_train, y_train)
    
    # Get the best model and parameters
    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_
    best_cv_score = -grid_search.best_score_  # Convert back from negative
    
    # Evaluate on test set
    y_pred = best_model.predict(X_test)
    test_mae = mean_absolute_error(y_test, y_pred)
    
    # Store results
    best_ride_models[ride] = best_model
    best_ride_params[ride] = best_params
    best_ride_mae_cv[ride] = {
        'cv_mae': best_cv_score,
        'test_mae': test_mae
    }
    
    print(f"  Best CV MAE: {best_cv_score:.2f}")
    print(f"  Test MAE: {test_mae:.2f}")
    print(f"  Best params: {best_params}")
    print()

print("Cross-validation completed!")
# Out:
# Starting cross-validation for each ride...
# This may take a few minutes...
#
# Processing ride 1/42: Guardians of the Galaxy - Mission: BREAKOUT!
#   Best CV MAE: 24.75
#   Test MAE: 24.62
#   Best params: {'colsample_bytree': 0.9, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 2/42: Golden Zephyr
#   Best CV MAE: 24.75
#   Test MAE: 24.62
#   Best params: {'colsample_bytree': 0.9, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 2/42: Golden Zephyr
#   Best CV MAE: 3.66
#   Test MAE: 5.47
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 3/42: Goofy's Sky School
#   Best CV MAE: 3.66
#   Test MAE: 5.47
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 3/42: Goofy's Sky School
#   Best CV MAE: 13.14
#   Test MAE: 15.30
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 150, 'subsample': 0.9}
#
# Processing ride 4/42: Silly Symphony Swings
#   Best CV MAE: 13.14
#   Test MAE: 15.30
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 150, 'subsample': 0.9}
#
# Processing ride 4/42: Silly Symphony Swings
#   Best CV MAE: 4.26
#   Test MAE: 5.74
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 5/42: Silly Symphony Swings Single Rider
#   Best CV MAE: 4.26
#   Test MAE: 5.74
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 5/42: Silly Symphony Swings Single Rider
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 6/42: The Little Mermaid - Ariel's Undersea Adventure
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 6/42: The Little Mermaid - Ariel's Undersea Adventure
#   Best CV MAE: 9.61
#   Test MAE: 9.89
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 7/42: Games of Pixar Pier
#   Best CV MAE: 9.61
#   Test MAE: 9.89
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 7/42: Games of Pixar Pier
#   Best CV MAE: 2.19
#   Test MAE: 2.34
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50, 'subsample': 0.9}
#
# Processing ride 8/42: Walt Disney Imagineering Blue Sky Cellar
#   Best CV MAE: 2.19
#   Test MAE: 2.34
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50, 'subsample': 0.9}
#
# Processing ride 8/42: Walt Disney Imagineering Blue Sky Cellar
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 9/42: Incredicoaster
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 9/42: Incredicoaster
#   Best CV MAE: 13.84
#   Test MAE: 15.35
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.9}
#
# Processing ride 10/42: Inside Out Emotional Whirlwind
#   Best CV MAE: 13.84
#   Test MAE: 15.35
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.9}
#
# Processing ride 10/42: Inside Out Emotional Whirlwind
#   Best CV MAE: 8.80
#   Test MAE: 7.74
#   Best params: {'colsample_bytree': 0.9, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}
#
# Processing ride 11/42: Jessie's Critter Carousel
#   Best CV MAE: 8.80
#   Test MAE: 7.74
#   Best params: {'colsample_bytree': 0.9, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}
#
# Processing ride 11/42: Jessie's Critter Carousel
#   Best CV MAE: 1.89
#   Test MAE: 1.90
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 1.0}
#
# Processing ride 12/42: Jumpin' Jellyfish
#   Best CV MAE: 1.89
#   Test MAE: 1.90
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 1.0}
#
# Processing ride 12/42: Jumpin' Jellyfish
#   Best CV MAE: 4.99
#   Test MAE: 5.90
#   Best params: {'colsample_bytree': 0.9, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}
#
# Processing ride 13/42: Pixar Pal-A-Round - Swinging
#   Best CV MAE: 4.99
#   Test MAE: 5.90
#   Best params: {'colsample_bytree': 0.9, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}
#
# Processing ride 13/42: Pixar Pal-A-Round - Swinging
#   Best CV MAE: 9.58
#   Test MAE: 11.48
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 150, 'subsample': 0.9}
#
# Processing ride 14/42: Pixar Pal-A-Round – Non-Swinging
#   Best CV MAE: 9.58
#   Test MAE: 11.48
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 150, 'subsample': 0.9}
#
# Processing ride 14/42: Pixar Pal-A-Round – Non-Swinging
#   Best CV MAE: 9.68
#   Test MAE: 10.97
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'subsample': 1.0}
#
# Processing ride 15/42: Toy Story Midway Mania!
#   Best CV MAE: 9.68
#   Test MAE: 10.97
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'subsample': 1.0}
#
# Processing ride 15/42: Toy Story Midway Mania!
#   Best CV MAE: 11.65
#   Test MAE: 12.34
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 16/42: Incredicoaster Single Rider
#   Best CV MAE: 11.65
#   Test MAE: 12.34
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 16/42: Incredicoaster Single Rider
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 17/42: The Bakery Tour
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 17/42: The Bakery Tour
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 18/42: World of Color – ONE
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 18/42: World of Color – ONE
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 19/42: Sorcerer's Workshop
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 19/42: Sorcerer's Workshop
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 20/42: Turtle Talk with Crush
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 20/42: Turtle Talk with Crush
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 21/42: WEB SLINGERS: A Spider-Man Adventure
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 21/42: WEB SLINGERS: A Spider-Man Adventure
#   Best CV MAE: 13.56
#   Test MAE: 14.52
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
#
# Processing ride 22/42: WEB SLINGERS: A Spider-Man Adventure Single Rider
#   Best CV MAE: 13.56
#   Test MAE: 14.52
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
#
# Processing ride 22/42: WEB SLINGERS: A Spider-Man Adventure Single Rider
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 23/42: Red Car Trolley
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 23/42: Red Car Trolley
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 24/42: Luigi's Rollickin' Roadsters
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 24/42: Luigi's Rollickin' Roadsters
#   Best CV MAE: 10.65
#   Test MAE: 9.42
#   Best params: {'colsample_bytree': 0.9, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
#
# Processing ride 25/42: Mater's Junkyard Jamboree
#   Best CV MAE: 10.65
#   Test MAE: 9.42
#   Best params: {'colsample_bytree': 0.9, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
#
# Processing ride 25/42: Mater's Junkyard Jamboree
#   Best CV MAE: 8.27
#   Test MAE: 7.60
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 26/42: Radiator Springs Racers
#   Best CV MAE: 8.27
#   Test MAE: 7.60
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 26/42: Radiator Springs Racers
#   Best CV MAE: 25.22
#   Test MAE: 27.95
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 27/42: Radiator Springs Racers Single Rider
#   Best CV MAE: 25.22
#   Test MAE: 27.95
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 27/42: Radiator Springs Racers Single Rider
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 28/42: Guardians of the Galaxy - Monsters After Dark
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 28/42: Guardians of the Galaxy - Monsters After Dark
#   Best CV MAE: 10.88
#   Test MAE: 5.92
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}
#
# Processing ride 29/42: Redwood Creek Challenge Trail
#   Best CV MAE: 10.88
#   Test MAE: 5.92
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}
#
# Processing ride 29/42: Redwood Creek Challenge Trail
#   Best CV MAE: 1.78
#   Test MAE: 1.76
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 150, 'subsample': 0.8}
#
# Processing ride 30/42: Soarin' Around the World
#   Best CV MAE: 1.78
#   Test MAE: 1.76
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 150, 'subsample': 0.8}
#
# Processing ride 30/42: Soarin' Around the World
#   Best CV MAE: 11.87
#   Test MAE: 22.58
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
#
# Processing ride 31/42: Animation Academy
#   Best CV MAE: 11.87
#   Test MAE: 22.58
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
#
# Processing ride 31/42: Animation Academy
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 32/42: Mickey's PhilharMagic
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 32/42: Mickey's PhilharMagic
#   Best CV MAE: 3.42
#   Test MAE: 3.27
#   Best params: {'colsample_bytree': 0.9, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.9}
#
# Processing ride 33/42: Monsters, Inc. Mike & Sulley to the Rescue!
#   Best CV MAE: 3.42
#   Test MAE: 3.27
#   Best params: {'colsample_bytree': 0.9, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.9}
#
# Processing ride 33/42: Monsters, Inc. Mike & Sulley to the Rescue!
#   Best CV MAE: 12.19
#   Test MAE: 13.05
#   Best params: {'colsample_bytree': 0.9, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
#
# Processing ride 34/42: Rogers: The Musical
#   Best CV MAE: 12.19
#   Test MAE: 13.05
#   Best params: {'colsample_bytree': 0.9, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
#
# Processing ride 34/42: Rogers: The Musical
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 35/42: Grizzly River Run
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 35/42: Grizzly River Run
#   Best CV MAE: 7.90
#   Test MAE: 13.81
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50, 'subsample': 1.0}
#
# Processing ride 36/42: Luigi's Honkin' Haul-O-Ween
#   Best CV MAE: 7.90
#   Test MAE: 13.81
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50, 'subsample': 1.0}
#
# Processing ride 36/42: Luigi's Honkin' Haul-O-Ween
#   Best CV MAE: 9.54
#   Test MAE: 15.78
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 150, 'subsample': 0.9}
#
# Processing ride 37/42: Mater's Graveyard JamBOOree
#   Best CV MAE: 9.54
#   Test MAE: 15.78
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 150, 'subsample': 0.9}
#
# Processing ride 37/42: Mater's Graveyard JamBOOree
#   Best CV MAE: 7.37
#   Test MAE: 8.31
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 38/42: Villains Grove at Oogie Boogie Bash
#   Best CV MAE: 7.37
#   Test MAE: 8.31
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 38/42: Villains Grove at Oogie Boogie Bash
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 39/42: Luigi's Joy to the Whirl
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 39/42: Luigi's Joy to the Whirl
#   Best CV MAE: 9.03
#   Test MAE: 12.71
#   Best params: {'colsample_bytree': 0.9, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 1.0}
#
# Processing ride 40/42: Mater's Jingle Jamboree
#   Best CV MAE: 9.03
#   Test MAE: 12.71
#   Best params: {'colsample_bytree': 0.9, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 1.0}
#
# Processing ride 40/42: Mater's Jingle Jamboree
#   Best CV MAE: 4.57
#   Test MAE: 6.48
#   Best params: {'colsample_bytree': 0.9, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 150, 'subsample': 0.9}
#
# Processing ride 41/42: World of Color - Season of Light
#   Best CV MAE: 4.57
#   Test MAE: 6.48
#   Best params: {'colsample_bytree': 0.9, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 150, 'subsample': 0.9}
#
# Processing ride 41/42: World of Color - Season of Light
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 42/42: Soarin' Over California
#   Best CV MAE: -0.00
#   Test MAE: 0.00
#   Best params: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
#
# Processing ride 42/42: Soarin' Over California
#   Best CV MAE: 15.39
#   Test MAE: 16.43
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.9}
#
# Cross-validation completed!
#   Best CV MAE: 15.39
#   Test MAE: 16.43
#   Best params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.9}
#
# Cross-validation completed!

# %%
# Display Comprehensive Results: Seasonal Naive vs Basic XGBoost vs Tuned XGBoost

# Calculate improvements
print("=" * 100)
print("COMPREHENSIVE MODEL COMPARISON")
print("=" * 100)
print()

# Determine the maximum length of ride names for formatting
max_ride_length = max(len(ride) for ride in ride_splits.keys())

# Print header
header = f"{'Ride':<{max_ride_length}} | {'Seasonal Naive':>15} | {'Basic XGBoost':>13} | {'Tuned XGBoost':>13} | {'CV MAE':>7} | {'Improvement':>11}"
print(header)
print("-" * len(header))

total_improvement_basic = 0
total_improvement_tuned = 0
ride_count = len(ride_splits)

# Print results for each ride
for ride in sorted(ride_splits.keys()):
    naive_mae = baseline_results.get(ride, float('nan'))
    basic_xgb_mae = ride_mae.get(ride, float('nan'))
    tuned_cv_mae = best_ride_mae_cv.get(ride, {}).get('cv_mae', float('nan'))
    tuned_test_mae = best_ride_mae_cv.get(ride, {}).get('test_mae', float('nan'))
    
    # Calculate improvement percentages
    if not np.isnan(naive_mae) and not np.isnan(tuned_test_mae) and naive_mae > 0:
        improvement = ((naive_mae - tuned_test_mae) / naive_mae) * 100
        total_improvement_tuned += improvement
    else:
        improvement = 0
        
    if not np.isnan(naive_mae) and not np.isnan(basic_xgb_mae) and naive_mae > 0:
        basic_improvement = ((naive_mae - basic_xgb_mae) / naive_mae) * 100
        total_improvement_basic += basic_improvement
    else:
        basic_improvement = 0
    
    print(f"{ride:<{max_ride_length}} | {naive_mae:>15.2f} | {basic_xgb_mae:>13.2f} | {tuned_test_mae:>13.2f} | {tuned_cv_mae:>7.2f} | {improvement:>10.1f}%")

print("-" * len(header))
print(f"{'AVERAGE IMPROVEMENT':<{max_ride_length}} | {'':<15} | {total_improvement_basic/ride_count:>12.1f}% | {total_improvement_tuned/ride_count:>12.1f}% | {'':<7} | {'':<11}")
print()

# Display best hyperparameters for each ride
print("BEST HYPERPARAMETERS FOR EACH RIDE:")
print("=" * 50)
for ride, params in best_ride_params.items():
    print(f"\n{ride}:")
    for param, value in params.items():
        print(f"  {param}: {value}")

# Summary statistics
print("\nSUMMARY STATISTICS:")
print("=" * 30)
tuned_maes = [result['test_mae'] for result in best_ride_mae_cv.values()]
print(f"Average Tuned XGBoost MAE: {np.mean(tuned_maes):.2f} ± {np.std(tuned_maes):.2f}")
print(f"Best performing ride: {min(best_ride_mae_cv.keys(), key=lambda k: best_ride_mae_cv[k]['test_mae'])}")
print(f"Worst performing ride: {max(best_ride_mae_cv.keys(), key=lambda k: best_ride_mae_cv[k]['test_mae'])}")
# Out:
# ====================================================================================================
# COMPREHENSIVE MODEL COMPARISON
# ====================================================================================================
#
# Ride                                              |  Seasonal Naive | Basic XGBoost | Tuned XGBoost |  CV MAE | Improvement
# ---------------------------------------------------------------------------------------------------------------------------
# Animation Academy                                 |            0.00 |          0.00 |          0.00 |   -0.00 |        0.0%
# Games of Pixar Pier                               |            2.46 |          2.38 |          2.34 |    2.19 |        4.9%
# Golden Zephyr                                     |            6.26 |          5.64 |          5.47 |    3.66 |       12.6%
# Goofy's Sky School                                |           23.17 |         15.15 |         15.30 |   13.14 |       33.9%
# Grizzly River Run                                 |           15.47 |         13.88 |         13.81 |    7.90 |       10.7%
# Guardians of the Galaxy - Mission: BREAKOUT!      |           33.87 |         25.46 |         24.62 |   24.75 |       27.3%
# Guardians of the Galaxy - Monsters After Dark     |           14.03 |          6.43 |          5.92 |   10.88 |       57.8%
# Incredicoaster                                    |           22.38 |         15.55 |         15.35 |   13.84 |       31.4%
# Incredicoaster Single Rider                       |            0.00 |          0.00 |          0.00 |   -0.00 |        0.0%
# Inside Out Emotional Whirlwind                    |           12.62 |          8.20 |          7.74 |    8.80 |       38.7%
# Jessie's Critter Carousel                         |            2.30 |          2.17 |          1.90 |    1.89 |       17.3%
# Jumpin' Jellyfish                                 |            7.02 |          6.54 |          5.90 |    4.99 |       16.0%
# Luigi's Honkin' Haul-O-Ween                       |           14.97 |         17.58 |         15.78 |    9.54 |       -5.4%
# Luigi's Joy to the Whirl                          |           15.19 |         12.83 |         12.71 |    9.03 |       16.3%
# Luigi's Rollickin' Roadsters                      |           15.86 |          9.45 |          9.42 |   10.65 |       40.6%
# Mater's Graveyard JamBOOree                       |           11.32 |          8.73 |          8.31 |    7.37 |       26.6%
# Mater's Jingle Jamboree                           |            8.84 |          6.58 |          6.48 |    4.57 |       26.7%
# Mater's Junkyard Jamboree                         |           12.25 |          7.50 |          7.60 |    8.27 |       37.9%
# Mickey's PhilharMagic                             |            4.33 |          3.23 |          3.27 |    3.42 |       24.6%
# Monsters, Inc. Mike & Sulley to the Rescue!       |           21.84 |         12.80 |         13.05 |   12.19 |       40.3%
# Pixar Pal-A-Round - Swinging                      |           19.78 |         11.92 |         11.48 |    9.58 |       42.0%
# Pixar Pal-A-Round – Non-Swinging                  |           18.51 |         11.07 |         10.97 |    9.68 |       40.7%
# Radiator Springs Racers                           |           37.97 |         29.09 |         27.95 |   25.22 |       26.4%
# Radiator Springs Racers Single Rider              |            0.00 |          0.00 |          0.00 |   -0.00 |        0.0%
# Red Car Trolley                                   |            0.00 |          0.00 |          0.00 |   -0.00 |        0.0%
# Redwood Creek Challenge Trail                     |            2.47 |          1.76 |          1.76 |    1.78 |       28.7%
# Rogers: The Musical                               |            0.00 |          0.00 |          0.00 |   -0.00 |        0.0%
# Silly Symphony Swings                             |            7.14 |          5.82 |          5.74 |    4.26 |       19.6%
# Silly Symphony Swings Single Rider                |            0.00 |          0.00 |          0.00 |   -0.00 |        0.0%
# Soarin' Around the World                          |           24.79 |         22.13 |         22.58 |   11.87 |        8.9%
# Soarin' Over California                           |           28.05 |         15.33 |         16.43 |   15.39 |       41.4%
# Sorcerer's Workshop                               |            0.00 |          0.00 |          0.00 |   -0.00 |        0.0%
# The Bakery Tour                                   |            0.00 |          0.00 |          0.00 |   -0.00 |        0.0%
# The Little Mermaid - Ariel's Undersea Adventure   |           14.35 |         10.24 |          9.89 |    9.61 |       31.1%
# Toy Story Midway Mania!                           |           21.41 |         12.41 |         12.34 |   11.65 |       42.3%
# Turtle Talk with Crush                            |            0.00 |          0.00 |          0.00 |   -0.00 |        0.0%
# Villains Grove at Oogie Boogie Bash               |            0.00 |          0.00 |          0.00 |   -0.00 |        0.0%
# WEB SLINGERS: A Spider-Man Adventure              |           21.94 |         14.93 |         14.52 |   13.56 |       33.8%
# WEB SLINGERS: A Spider-Man Adventure Single Rider |            0.00 |          0.00 |          0.00 |   -0.00 |        0.0%
# Walt Disney Imagineering Blue Sky Cellar          |            0.00 |          0.00 |          0.00 |   -0.00 |        0.0%
# World of Color - Season of Light                  |            0.00 |          0.00 |          0.00 |   -0.00 |        0.0%
# World of Color – ONE                              |            0.00 |          0.00 |          0.00 |   -0.00 |        0.0%
# ---------------------------------------------------------------------------------------------------------------------------
# AVERAGE IMPROVEMENT                               |                 |         17.1% |         18.4% |         |
#
# BEST HYPERPARAMETERS FOR EACH RIDE:
# ==================================================
#
# Guardians of the Galaxy - Mission: BREAKOUT!:
#   colsample_bytree: 0.9
#   learning_rate: 0.1
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# Golden Zephyr:
#   colsample_bytree: 1.0
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# Goofy's Sky School:
#   colsample_bytree: 1.0
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 150
#   subsample: 0.9
#
# Silly Symphony Swings:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 7
#   n_estimators: 50
#   subsample: 0.8
#
# Silly Symphony Swings Single Rider:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# The Little Mermaid - Ariel's Undersea Adventure:
#   colsample_bytree: 1.0
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# Games of Pixar Pier:
#   colsample_bytree: 0.8
#   learning_rate: 0.1
#   max_depth: 7
#   n_estimators: 50
#   subsample: 0.9
#
# Walt Disney Imagineering Blue Sky Cellar:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# Incredicoaster:
#   colsample_bytree: 0.8
#   learning_rate: 0.1
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.9
#
# Inside Out Emotional Whirlwind:
#   colsample_bytree: 0.9
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 100
#   subsample: 1.0
#
# Jessie's Critter Carousel:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 1.0
#
# Jumpin' Jellyfish:
#   colsample_bytree: 0.9
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 100
#   subsample: 1.0
#
# Pixar Pal-A-Round - Swinging:
#   colsample_bytree: 0.8
#   learning_rate: 0.1
#   max_depth: 3
#   n_estimators: 150
#   subsample: 0.9
#
# Pixar Pal-A-Round – Non-Swinging:
#   colsample_bytree: 1.0
#   learning_rate: 0.05
#   max_depth: 5
#   n_estimators: 100
#   subsample: 1.0
#
# Toy Story Midway Mania!:
#   colsample_bytree: 1.0
#   learning_rate: 0.05
#   max_depth: 7
#   n_estimators: 50
#   subsample: 0.8
#
# Incredicoaster Single Rider:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# The Bakery Tour:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# World of Color – ONE:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# Sorcerer's Workshop:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# Turtle Talk with Crush:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# WEB SLINGERS: A Spider-Man Adventure:
#   colsample_bytree: 1.0
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 100
#   subsample: 0.8
#
# WEB SLINGERS: A Spider-Man Adventure Single Rider:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# Red Car Trolley:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# Luigi's Rollickin' Roadsters:
#   colsample_bytree: 0.9
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 100
#   subsample: 0.8
#
# Mater's Junkyard Jamboree:
#   colsample_bytree: 1.0
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# Radiator Springs Racers:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# Radiator Springs Racers Single Rider:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# Guardians of the Galaxy - Monsters After Dark:
#   colsample_bytree: 1.0
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 100
#   subsample: 1.0
#
# Redwood Creek Challenge Trail:
#   colsample_bytree: 1.0
#   learning_rate: 0.05
#   max_depth: 5
#   n_estimators: 150
#   subsample: 0.8
#
# Soarin' Around the World:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 100
#   subsample: 0.8
#
# Animation Academy:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# Mickey's PhilharMagic:
#   colsample_bytree: 0.9
#   learning_rate: 0.1
#   max_depth: 5
#   n_estimators: 50
#   subsample: 0.9
#
# Monsters, Inc. Mike & Sulley to the Rescue!:
#   colsample_bytree: 0.9
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 100
#   subsample: 0.8
#
# Rogers: The Musical:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# Grizzly River Run:
#   colsample_bytree: 1.0
#   learning_rate: 0.1
#   max_depth: 7
#   n_estimators: 50
#   subsample: 1.0
#
# Luigi's Honkin' Haul-O-Ween:
#   colsample_bytree: 0.8
#   learning_rate: 0.2
#   max_depth: 5
#   n_estimators: 150
#   subsample: 0.9
#
# Mater's Graveyard JamBOOree:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 7
#   n_estimators: 50
#   subsample: 0.8
#
# Villains Grove at Oogie Boogie Bash:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# Luigi's Joy to the Whirl:
#   colsample_bytree: 0.9
#   learning_rate: 0.1
#   max_depth: 3
#   n_estimators: 50
#   subsample: 1.0
#
# Mater's Jingle Jamboree:
#   colsample_bytree: 0.9
#   learning_rate: 0.05
#   max_depth: 5
#   n_estimators: 150
#   subsample: 0.9
#
# World of Color - Season of Light:
#   colsample_bytree: 0.8
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.8
#
# Soarin' Over California:
#   colsample_bytree: 1.0
#   learning_rate: 0.05
#   max_depth: 3
#   n_estimators: 50
#   subsample: 0.9
#
# SUMMARY STATISTICS:
# ==============================
# Average Tuned XGBoost MAE: 7.35 ± 7.44
# Best performing ride: Silly Symphony Swings Single Rider
# Worst performing ride: Radiator Springs Racers

# %%
# Feature Importance Analysis from Best Models

import matplotlib.pyplot as plt

print("FEATURE IMPORTANCE ANALYSIS")
print("=" * 40)

# Calculate average feature importance across all rides
feature_importance_sum = {}
feature_count = {}

for ride, model in best_ride_models.items():
    # Get feature names and importances
    feature_names = ride_splits[ride]['X_train'].columns
    importances = model.feature_importances_
    
    print(f"\nTop 10 features for {ride}:")
    # Sort features by importance
    feature_importance_pairs = list(zip(feature_names, importances))
    feature_importance_pairs.sort(key=lambda x: x[1], reverse=True)
    
    for i, (feature, importance) in enumerate(feature_importance_pairs[:10]):
        print(f"  {i+1:2d}. {feature:<30} {importance:.4f}")
        
        # Add to global sum for averaging
        if feature in feature_importance_sum:
            feature_importance_sum[feature] += importance
            feature_count[feature] += 1
        else:
            feature_importance_sum[feature] = importance
            feature_count[feature] = 1

# Calculate average importance across all rides
avg_feature_importance = {feature: feature_importance_sum[feature] / feature_count[feature] 
                         for feature in feature_importance_sum}

# Sort by average importance
sorted_avg_features = sorted(avg_feature_importance.items(), key=lambda x: x[1], reverse=True)

print(f"\n\nAVERAGE FEATURE IMPORTANCE ACROSS ALL RIDES:")
print("=" * 50)
for i, (feature, avg_importance) in enumerate(sorted_avg_features[:15]):
    print(f"{i+1:2d}. {feature:<35} {avg_importance:.4f}")

# Create a visualization of top features
top_features = sorted_avg_features[:10]
features, importances = zip(*top_features)

plt.figure(figsize=(12, 6))
plt.barh(range(len(features)), importances)
plt.yticks(range(len(features)), features)
plt.xlabel('Average Feature Importance')
plt.title('Top 10 Most Important Features Across All Rides')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

print(f"\nNote: Feature importance is calculated using XGBoost's built-in feature importance,")
print(f"which measures the average gain of splits using each feature across all trees.")
# Out:
# FEATURE IMPORTANCE ANALYSIS
# ========================================
#
# Top 10 features for Guardians of the Galaxy - Mission: BREAKOUT!:
#    1. month                          0.3068
#    2. hour                           0.1348
#    3. tier_4                         0.0534
#    4. temperature_2m (°F)            0.0529
#    5. tier_2                         0.0507
#    6. tier_0                         0.0489
#    7. tier_3                         0.0460
#    8. apparent_temperature (°F)      0.0455
#    9. day_of_week                    0.0386
#   10. tier_1                         0.0378
#
# Top 10 features for Golden Zephyr:
#    1. tier_6                         0.2243
#    2. temperature_2m (°F)            0.1277
#    3. holiday_name_Washington's Birthday 0.1248
#    4. hour                           0.1221
#    5. apparent_temperature (°F)      0.1113
#    6. month                          0.1104
#    7. holiday_name_Christmas Day     0.0816
#    8. day_of_week                    0.0805
#    9. tier_0                         0.0099
#   10. tier_3                         0.0075
#
# Top 10 features for Goofy's Sky School:
#    1. hour                           0.2608
#    2. precipitation (mm)             0.1363
#    3. tier_6                         0.1342
#    4. month                          0.0743
#    5. holiday_name_Washington's Birthday 0.0503
#    6. temperature_2m (°F)            0.0468
#    7. holiday_flag                   0.0392
#    8. day_of_week                    0.0389
#    9. tier_3                         0.0379
#   10. apparent_temperature (°F)      0.0371
#
# Top 10 features for Silly Symphony Swings:
#    1. hour                           0.1293
#    2. tier_6                         0.1153
#    3. holiday_name_Washington's Birthday 0.1068
#    4. month                          0.0686
#    5. tier_3                         0.0669
#    6. holiday_name_Martin Luther King Jr. Day 0.0449
#    7. tier_4                         0.0434
#    8. tier_1                         0.0419
#    9. tier_2                         0.0410
#   10. tier_0                         0.0386
#
# Top 10 features for Silly Symphony Swings Single Rider:
#    1. hour                           0.0000
#    2. day_of_week                    0.0000
#    3. month                          0.0000
#    4. is_weekend                     0.0000
#    5. temperature_2m (°F)            0.0000
#    6. apparent_temperature (°F)      0.0000
#    7. precipitation (mm)             0.0000
#    8. holiday_flag                   0.0000
#    9. tier_0                         0.0000
#   10. tier_1                         0.0000
#
# Top 10 features for The Little Mermaid - Ariel's Undersea Adventure:
#    1. hour                           0.2377
#    2. tier_6                         0.1615
#    3. month                          0.1354
#    4. apparent_temperature (°F)      0.0942
#    5. tier_4                         0.0653
#    6. precipitation (mm)             0.0609
#    7. holiday_name_Washington's Birthday 0.0561
#    8. temperature_2m (°F)            0.0509
#    9. tier_1                         0.0508
#   10. day_of_week                    0.0457
#
# Top 10 features for Games of Pixar Pier:
#    1. tier_6                         0.0745
#    2. tier_4                         0.0734
#    3. tier_5                         0.0704
#    4. holiday_name_Veterans Day      0.0690
#    5. month                          0.0678
#    6. holiday_name_New Year's Day    0.0569
#    7. tier_0                         0.0535
#    8. day_of_week                    0.0534
#    9. apparent_temperature (°F)      0.0500
#   10. tier_2                         0.0492
#
# Top 10 features for Walt Disney Imagineering Blue Sky Cellar:
#    1. hour                           0.0000
#    2. day_of_week                    0.0000
#    3. month                          0.0000
#    4. is_weekend                     0.0000
#    5. temperature_2m (°F)            0.0000
#    6. apparent_temperature (°F)      0.0000
#    7. precipitation (mm)             0.0000
#    8. holiday_flag                   0.0000
#    9. tier_3                         0.0000
#   10. tier_4                         0.0000
#
# Top 10 features for Incredicoaster:
#    1. hour                           0.2299
#    2. tier_6                         0.1672
#    3. precipitation (mm)             0.0771
#    4. month                          0.0751
#    5. tier_4                         0.0551
#    6. apparent_temperature (°F)      0.0538
#    7. tier_5                         0.0500
#    8. tier_3                         0.0470
#    9. temperature_2m (°F)            0.0470
#   10. tier_1                         0.0441
#
# Top 10 features for Inside Out Emotional Whirlwind:
#    1. hour                           0.2418
#    2. month                          0.1511
#    3. tier_6                         0.1314
#    4. apparent_temperature (°F)      0.0684
#    5. tier_1                         0.0561
#    6. tier_4                         0.0514
#    7. temperature_2m (°F)            0.0496
#    8. precipitation (mm)             0.0371
#    9. tier_5                         0.0370
#   10. tier_2                         0.0338
#
# Top 10 features for Jessie's Critter Carousel:
#    1. hour                           0.1495
#    2. precipitation (mm)             0.1215
#    3. tier_1                         0.1029
#    4. temperature_2m (°F)            0.1016
#    5. apparent_temperature (°F)      0.0963
#    6. month                          0.0912
#    7. day_of_week                    0.0869
#    8. holiday_name_Washington's Birthday 0.0676
#    9. is_weekend                     0.0602
#   10. tier_0                         0.0430
#
# Top 10 features for Jumpin' Jellyfish:
#    1. hour                           0.1649
#    2. tier_6                         0.1282
#    3. month                          0.1082
#    4. precipitation (mm)             0.0743
#    5. holiday_name_Christmas Day     0.0604
#    6. holiday_name_Washington's Birthday 0.0575
#    7. is_weekend                     0.0538
#    8. tier_2                         0.0507
#    9. day_of_week                    0.0498
#   10. apparent_temperature (°F)      0.0445
#
# Top 10 features for Pixar Pal-A-Round - Swinging:
#    1. hour                           0.3239
#    2. precipitation (mm)             0.1184
#    3. tier_6                         0.1174
#    4. month                          0.0537
#    5. apparent_temperature (°F)      0.0471
#    6. holiday_name_Washington's Birthday 0.0435
#    7. temperature_2m (°F)            0.0431
#    8. tier_3                         0.0326
#    9. tier_1                         0.0324
#   10. tier_0                         0.0304
#
# Top 10 features for Pixar Pal-A-Round – Non-Swinging:
#    1. hour                           0.2564
#    2. tier_6                         0.1206
#    3. precipitation (mm)             0.1172
#    4. apparent_temperature (°F)      0.0768
#    5. tier_3                         0.0495
#    6. month                          0.0484
#    7. holiday_name_Washington's Birthday 0.0451
#    8. tier_0                         0.0306
#    9. tier_2                         0.0304
#   10. day_of_week                    0.0297
#
# Top 10 features for Toy Story Midway Mania!:
#    1. hour                           0.2700
#    2. tier_6                         0.0853
#    3. precipitation (mm)             0.0632
#    4. holiday_name_New Year's Day    0.0565
#    5. holiday_name_Martin Luther King Jr. Day 0.0449
#    6. apparent_temperature (°F)      0.0444
#    7. tier_2                         0.0435
#    8. holiday_flag                   0.0355
#    9. month                          0.0336
#   10. temperature_2m (°F)            0.0331
#
# Top 10 features for Incredicoaster Single Rider:
#    1. hour                           0.0000
#    2. day_of_week                    0.0000
#    3. month                          0.0000
#    4. is_weekend                     0.0000
#    5. temperature_2m (°F)            0.0000
#    6. apparent_temperature (°F)      0.0000
#    7. precipitation (mm)             0.0000
#    8. holiday_flag                   0.0000
#    9. tier_0                         0.0000
#   10. tier_1                         0.0000
#
# Top 10 features for The Bakery Tour:
#    1. hour                           0.0000
#    2. day_of_week                    0.0000
#    3. month                          0.0000
#    4. is_weekend                     0.0000
#    5. temperature_2m (°F)            0.0000
#    6. apparent_temperature (°F)      0.0000
#    7. precipitation (mm)             0.0000
#    8. holiday_flag                   0.0000
#    9. tier_0                         0.0000
#   10. tier_1                         0.0000
#
# Top 10 features for World of Color – ONE:
#    1. hour                           0.0000
#    2. day_of_week                    0.0000
#    3. month                          0.0000
#    4. is_weekend                     0.0000
#    5. temperature_2m (°F)            0.0000
#    6. apparent_temperature (°F)      0.0000
#    7. precipitation (mm)             0.0000
#    8. holiday_flag                   0.0000
#    9. tier_0                         0.0000
#   10. tier_1                         0.0000
#
# Top 10 features for Sorcerer's Workshop:
#    1. hour                           0.0000
#    2. day_of_week                    0.0000
#    3. month                          0.0000
#    4. is_weekend                     0.0000
#    5. temperature_2m (°F)            0.0000
#    6. apparent_temperature (°F)      0.0000
#    7. precipitation (mm)             0.0000
#    8. holiday_flag                   0.0000
#    9. tier_0                         0.0000
#   10. tier_1                         0.0000
#
# Top 10 features for Turtle Talk with Crush:
#    1. hour                           0.0000
#    2. day_of_week                    0.0000
#    3. month                          0.0000
#    4. is_weekend                     0.0000
#    5. temperature_2m (°F)            0.0000
#    6. apparent_temperature (°F)      0.0000
#    7. precipitation (mm)             0.0000
#    8. holiday_flag                   0.0000
#    9. tier_0                         0.0000
#   10. tier_1                         0.0000
#
# Top 10 features for WEB SLINGERS: A Spider-Man Adventure:
#    1. hour                           0.2413
#    2. tier_6                         0.1306
#    3. tier_4                         0.0841
#    4. month                          0.0746
#    5. apparent_temperature (°F)      0.0654
#    6. precipitation (mm)             0.0635
#    7. tier_5                         0.0484
#    8. tier_2                         0.0429
#    9. holiday_name_Thanksgiving Day  0.0428
#   10. temperature_2m (°F)            0.0405
#
# Top 10 features for WEB SLINGERS: A Spider-Man Adventure Single Rider:
#    1. hour                           0.0000
#    2. day_of_week                    0.0000
#    3. month                          0.0000
#    4. is_weekend                     0.0000
#    5. temperature_2m (°F)            0.0000
#    6. apparent_temperature (°F)      0.0000
#    7. precipitation (mm)             0.0000
#    8. holiday_flag                   0.0000
#    9. tier_0                         0.0000
#   10. tier_1                         0.0000
#
# Top 10 features for Red Car Trolley:
#    1. hour                           0.0000
#    2. day_of_week                    0.0000
#    3. month                          0.0000
#    4. is_weekend                     0.0000
#    5. temperature_2m (°F)            0.0000
#    6. apparent_temperature (°F)      0.0000
#    7. precipitation (mm)             0.0000
#    8. holiday_flag                   0.0000
#    9. tier_0                         0.0000
#   10. tier_1                         0.0000
#
# Top 10 features for Luigi's Rollickin' Roadsters:
#    1. precipitation (mm)             0.3642
#    2. hour                           0.1492
#    3. temperature_2m (°F)            0.0843
#    4. tier_6                         0.0626
#    5. month                          0.0566
#    6. tier_1                         0.0427
#    7. day_of_week                    0.0395
#    8. tier_5                         0.0374
#    9. holiday_name_Washington's Birthday 0.0330
#   10. apparent_temperature (°F)      0.0315
#
# Top 10 features for Mater's Junkyard Jamboree:
#    1. month                          0.1283
#    2. tier_5                         0.1124
#    3. hour                           0.1123
#    4. tier_2                         0.1060
#    5. temperature_2m (°F)            0.1025
#    6. tier_6                         0.0895
#    7. precipitation (mm)             0.0794
#    8. apparent_temperature (°F)      0.0752
#    9. day_of_week                    0.0516
#   10. holiday_name_Washington's Birthday 0.0513
#
# Top 10 features for Radiator Springs Racers:
#    1. tier_6                         0.3864
#    2. month                          0.0947
#    3. tier_3                         0.0764
#    4. hour                           0.0685
#    5. precipitation (mm)             0.0679
#    6. holiday_name_Washington's Birthday 0.0656
#    7. temperature_2m (°F)            0.0612
#    8. apparent_temperature (°F)      0.0602
#    9. day_of_week                    0.0470
#   10. tier_4                         0.0249
#
# Top 10 features for Radiator Springs Racers Single Rider:
#    1. hour                           0.0000
#    2. day_of_week                    0.0000
#    3. month                          0.0000
#    4. is_weekend                     0.0000
#    5. temperature_2m (°F)            0.0000
#    6. apparent_temperature (°F)      0.0000
#    7. precipitation (mm)             0.0000
#    8. holiday_flag                   0.0000
#    9. tier_0                         0.0000
#   10. tier_1                         0.0000
#
# Top 10 features for Guardians of the Galaxy - Monsters After Dark:
#    1. month                          0.5279
#    2. hour                           0.2359
#    3. tier_4                         0.1028
#    4. apparent_temperature (°F)      0.0396
#    5. tier_0                         0.0300
#    6. day_of_week                    0.0289
#    7. temperature_2m (°F)            0.0138
#    8. tier_1                         0.0099
#    9. holiday_name_Labor Day         0.0066
#   10. tier_6                         0.0044
#
# Top 10 features for Redwood Creek Challenge Trail:
#    1. hour                           0.1918
#    2. month                          0.0823
#    3. holiday_flag                   0.0728
#    4. tier_0                         0.0669
#    5. holiday_name_Christmas Day     0.0558
#    6. holiday_name_Washington's Birthday 0.0479
#    7. tier_4                         0.0453
#    8. holiday_name_Veterans Day      0.0441
#    9. holiday_name_New Year's Day    0.0435
#   10. tier_5                         0.0412
#
# Top 10 features for Soarin' Around the World:
#    1. hour                           0.2786
#    2. tier_6                         0.1040
#    3. month                          0.0748
#    4. apparent_temperature (°F)      0.0570
#    5. holiday_name_New Year's Day    0.0480
#    6. temperature_2m (°F)            0.0479
#    7. day_of_week                    0.0469
#    8. tier_4                         0.0468
#    9. holiday_flag                   0.0426
#   10. tier_1                         0.0419
#
# Top 10 features for Animation Academy:
#    1. hour                           0.0000
#    2. day_of_week                    0.0000
#    3. month                          0.0000
#    4. is_weekend                     0.0000
#    5. temperature_2m (°F)            0.0000
#    6. apparent_temperature (°F)      0.0000
#    7. precipitation (mm)             0.0000
#    8. holiday_flag                   0.0000
#    9. tier_0                         0.0000
#   10. tier_1                         0.0000
#
# Top 10 features for Mickey's PhilharMagic:
#    1. hour                           0.1814
#    2. tier_4                         0.1050
#    3. holiday_name_Veterans Day      0.0698
#    4. tier_5                         0.0694
#    5. day_of_week                    0.0671
#    6. month                          0.0634
#    7. holiday_name_New Year's Day    0.0601
#    8. tier_3                         0.0495
#    9. apparent_temperature (°F)      0.0437
#   10. holiday_flag                   0.0431
#
# Top 10 features for Monsters, Inc. Mike & Sulley to the Rescue!:
#    1. hour                           0.3665
#    2. tier_6                         0.1144
#    3. apparent_temperature (°F)      0.0704
#    4. precipitation (mm)             0.0533
#    5. temperature_2m (°F)            0.0494
#    6. month                          0.0456
#    7. tier_2                         0.0379
#    8. day_of_week                    0.0315
#    9. tier_4                         0.0315
#   10. tier_5                         0.0310
#
# Top 10 features for Rogers: The Musical:
#    1. hour                           0.0000
#    2. day_of_week                    0.0000
#    3. month                          0.0000
#    4. is_weekend                     0.0000
#    5. temperature_2m (°F)            0.0000
#    6. apparent_temperature (°F)      0.0000
#    7. precipitation (mm)             0.0000
#    8. holiday_flag                   0.0000
#    9. tier_3                         0.0000
#   10. tier_4                         0.0000
#
# Top 10 features for Grizzly River Run:
#    1. temperature_2m (°F)            0.2980
#    2. month                          0.1345
#    3. apparent_temperature (°F)      0.0917
#    4. tier_6                         0.0836
#    5. hour                           0.0609
#    6. tier_3                         0.0444
#    7. day_of_week                    0.0408
#    8. tier_1                         0.0401
#    9. tier_4                         0.0342
#   10. holiday_name_Christmas Day     0.0339
#
# Top 10 features for Luigi's Honkin' Haul-O-Ween:
#    1. tier_2                         0.6558
#    2. day_of_week                    0.0723
#    3. is_weekend                     0.0602
#    4. hour                           0.0407
#    5. temperature_2m (°F)            0.0399
#    6. tier_3                         0.0351
#    7. tier_0                         0.0273
#    8. apparent_temperature (°F)      0.0271
#    9. tier_5                         0.0240
#   10. tier_4                         0.0120
#
# Top 10 features for Mater's Graveyard JamBOOree:
#    1. hour                           0.1304
#    2. day_of_week                    0.1169
#    3. tier_6                         0.1156
#    4. precipitation (mm)             0.0795
#    5. temperature_2m (°F)            0.0760
#    6. tier_1                         0.0656
#    7. apparent_temperature (°F)      0.0568
#    8. tier_3                         0.0546
#    9. tier_2                         0.0529
#   10. tier_4                         0.0514
#
# Top 10 features for Villains Grove at Oogie Boogie Bash:
#    1. hour                           0.0000
#    2. day_of_week                    0.0000
#    3. month                          0.0000
#    4. is_weekend                     0.0000
#    5. temperature_2m (°F)            0.0000
#    6. apparent_temperature (°F)      0.0000
#    7. precipitation (mm)             0.0000
#    8. holiday_flag                   0.0000
#    9. tier_0                         0.0000
#   10. tier_1                         0.0000
#
# Top 10 features for Luigi's Joy to the Whirl:
#    1. hour                           0.1510
#    2. apparent_temperature (°F)      0.1441
#    3. month                          0.0969
#    4. tier_3                         0.0932
#    5. holiday_name_Christmas Day     0.0797
#    6. tier_6                         0.0703
#    7. tier_2                         0.0637
#    8. holiday_flag                   0.0573
#    9. is_weekend                     0.0526
#   10. temperature_2m (°F)            0.0500
#
# Top 10 features for Mater's Jingle Jamboree:
#    1. tier_6                         0.2214
#    2. hour                           0.1005
#    3. tier_4                         0.0853
#    4. holiday_name_Thanksgiving Day  0.0809
#    5. month                          0.0690
#    6. tier_3                         0.0670
#    7. is_weekend                     0.0548
#    8. tier_5                         0.0541
#    9. precipitation (mm)             0.0507
#   10. apparent_temperature (°F)      0.0491
#
# Top 10 features for World of Color - Season of Light:
#    1. hour                           0.0000
#    2. day_of_week                    0.0000
#    3. month                          0.0000
#    4. is_weekend                     0.0000
#    5. temperature_2m (°F)            0.0000
#    6. apparent_temperature (°F)      0.0000
#    7. precipitation (mm)             0.0000
#    8. holiday_flag                   0.0000
#    9. tier_1                         0.0000
#   10. tier_2                         0.0000
#
# Top 10 features for Soarin' Over California:
#    1. hour                           0.3284
#    2. month                          0.1645
#    3. tier_3                         0.1305
#    4. tier_2                         0.0945
#    5. day_of_week                    0.0765
#    6. temperature_2m (°F)            0.0716
#    7. apparent_temperature (°F)      0.0558
#    8. tier_5                         0.0426
#    9. precipitation (mm)             0.0356
#   10. is_weekend                     0.0000
#
#
# AVERAGE FEATURE IMPORTANCE ACROSS ALL RIDES:
# ==================================================
#  1. tier_6                              0.1292
#  2. hour                                0.1258
#  3. tier_2                              0.0902
#  4. month                               0.0734
#  5. holiday_name_Washington's Birthday  0.0625
#  6. holiday_name_Christmas Day          0.0623
#  7. holiday_name_Thanksgiving Day       0.0618
#  8. holiday_name_Veterans Day           0.0610
#  9. holiday_name_New Year's Day         0.0530
# 10. precipitation (mm)                  0.0516
# 11. tier_5                              0.0515
# 12. tier_4                              0.0508
# 13. tier_3                              0.0493
# 14. holiday_name_Martin Luther King Jr. Day 0.0449
# 15. temperature_2m (°F)                 0.0425
# Note: Feature importance is calculated using XGBoost's built-in feature importance,
# which measures the average gain of splits using each feature across all trees.
